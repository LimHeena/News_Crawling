# %% [markdown]
# ## 문서요약

# %% [markdown]
# ## 강사님 코드 따라해보기

# %%
# !pip install 'networkx<2.7'

# %%
# !sudo apt-get install g++ openjdk-7-jdk # Install Java 1.7+
# !sudo apt-get install python-dev; pip install konlpy     # Python 2.x
# !sudo apt-get install python3-dev; pip3 install konlpy   # Python 3.x
# !sudo apt-get install curl
# !bash <(curl -s https://raw.githubusercontent.com/konlpy/konlpy/master/scripts/mecab.sh)

# %%
# %pip install mecab-python3

# %%
doc = """업종을 가리지 않고 다양한 국내 기업들이 우주산업을 ‘미래 먹거리’로 주목하고 있다. 여러 우주산업 분야 중에서도 특히 비교적 진출 문턱이 낮은 ‘스페이스 데이터(Space Data)’에서 기회를 잡겠단 청사진을 그렸다.

26일 업계에 따르면 정보통신기술(ICT) 업체부터 방산 기업까지 정부의 우주산업 육성 계획에 맞춰 스페이스 데이터 시장 진출을 준비하고 있다. ‘우주 데이터 산업의 쌀’로 비유되는 스페이스 데이터는 인공위성에서 촬영한 지구 관측 영상·이미지 등 우주를 통해 오가는 다양한 정보들을 통틀어 부르는 말이다. 인공지능(AI)·빅데이터 등을 활용해 △국토·자원 관리 △재해·재난 대응 △농업 △금융 △부동산 △물류 △환경 등 매우 다양한 산업에서 새로운 사업적 가치가 창출될 것으로 기대받는 분야다.

정부는 과학기술정보통신부(과기정통부)를 중심으로 스페이스 데이터 시장의 기반이 되는 인공위성 분야는 물론 우주 발사체 등을 개발하는 사업을 추진하고 있다. 이를 통해 민간 주도의 우주산업 생태계를 육성하겠단 목표를 세웠다.

전통적인 ICT 기업인 이동통신 3사(SK텔레콤·KT·LG유플러스, 이하 이통3사)는 이 같은 분위기를 반영, 인공위성을 기반으로 한 데이터 시장을 차세대 사업으로 선정했다. 네이버·한글과컴퓨터(한컴) 등 플랫폼 기업도 마찬가지다. 이들 기업은 그간 쌓아온 자사 인프라에 ‘스페이스 데이터’를 추가하는 식으로 사업을 구상 중이다.

최근에는 방산 기업인 LIG넥스원과 한국항공우주산업(KAI) 등도 해당 시장에서 사업적 성과를 올리기 위해 협업의 폭을 확대하고 있다. 스페이스 데이터뿐 아니라 인공위성 제작에도 관심을 나타내며 사업 영역을 넓히기 위한 전략을 추진 중이다.

국내 굴지의 기업들이 스페이스 데이터 시장에 주목하는 이유는 국내 우주산업 생태계의 모습이 반영된 현상으로 보인다. 정부 발표에 따르면 2020년 기준 우리나라 우주산업 규모는 3조2610억원 수준이다. 세계 우주산업 시장 규모는 2019년 기준 2707억달러(약 300조원)이고, 각 정부의 우주개발 예산을 포함하면 3660억달러(약 450조원)까지 증가한다. 우리나라 우주산업은 이 중 약 1%를 차지하고 있을 정도로 영세하다.

이마저도 위성방송통신·항법 분야가 2조5378억원을 기록, 전체의 78%를 차지하고 있을 정도로 치우쳐있다. 위성제조는 3249억원(10%), 발사체 제작은 1913억원(6%)으로 그 규모가 무척 작다.

우주 산업계 관계자는 “국내 다양한 기업들이 스페이스 데이터 사업에서 새로운 기회를 발굴하고자 하는 이유는 해당 분야의 성장 가능성을 반영한 것”이라면서도 “국내 우주산업 생태계를 고려하면 사업적 성과를 올릴 수 있다고 판단되는 분야가 사실상 스페이스 데이터 뿐이기도 하다”고 말했다.

누리호 2차 발사의 성공으로 우리나라는 세계에서 7번째로 1.5t급 실용위성을 자체적으로 지구궤도에 올릴 수 있는 국가가 됐다. 그러나 발사체·위성 등 우주기기를 제작할 수 있는 민간의 능력은 현저하게 떨어진다. 업계 관계자는 “우리나라 기업 중 발사체·위성 제작 분야에 진출해 세계 시장에서 유의미한 성과를 낼 수 있는 곳은 없다”며 “스페이스 데이터 외 다른 분야에 진출하고 싶어도 기업 입장에선 리스크(위험성)가 커 선뜻 나서기 힘들다”고 강조했다. 성장성이 담보됐다고 평가되는 우주산업이지만 현재 국내 수준으론 진출 분야가 한정적이란 설명이다.

국내 기업이 거의 유일하게 진출할 수 있는 스페이스 데이터 시장이지만, 기회는 충분하단 평가가 나온다. 또 다른 우주 산업계 관계자는 국내 기업이 스페이스 데이터 사업에서 올릴 수 있는 성과가 많다고 설명했다. 그는 “인공위성을 통해 확보한 데이터를 사용하는 곳은 결국 지상”이라며 “IT강국을 이끄는 국내 기업들이 보유한 인공지능(AI)·통신·보안 등의 기술을 통해 데이터를 재가공하면 세계 시장에서 충분히 성과를 낼 수 있을 것”이라고 말했다.

정부의 지원 역시 기대되는 요소로 꼽힌다. 정부는 2022년부터 2031년까지 공공목적의 위성을 총 170여기 개발하고, 위성개발과 연계해 국내 발사체 발사도 총 40여회 추진한다. 이 과정을 국내 기업과 함께 진행, 민간이 자연스럽게 기술을 습득하도록 사업을 기획했다.

누리호의 성공 역시 스페이스 데이터 분야의 성장을 촉진할 요소다. 정부는 누리호의 기술을 민간에 이전해 우주산업 생태계를 키우겠단 계획을 진행하고 있다. 오는 9월엔 누리호의 기술을 이전받는 ‘체계종합기업 우선협상대상자’가 선정된다. 우리나라에서도 기업 간 협업을 통해 민간위성 발사가 가능해진단 의미다. 정부는 이와 관련 고흥 나로우주센터 내 ‘민간기업 전용 발사체 발사장’을 건설할 방침이다. 민간이 우주 운송 수단을 확보하게 된다면 자연스럽게 국내 스페이스 데이터 시장의 규모도 커질 수 있는 구조다.

미국 투자은행 모건스탠리는 글로벌 우주산업 규모가 2018년 3500억달러(약 420조원)에서 오는 2040년 1조1000억달러(약 1320조원)까지 연평균 5.3% 성장하리라 전망했다. 이에 따라 스페이스 데이터 시장의 성장도 가파를 것으로 분석된다. 마켓츠앤마켓츠는 위성 이미지 데이터 시장 규모가 2021년 59억달러(약 7조원)에서 2026년에는 그 규모가 3배 이상 성장, 167억달러(약 21조원)에 이를 것으로 봤다.

시장 변화에 민감한 이통3사는 ‘우주산업의 성장’에 맞춰 다양한 전략을 추진하고 있다. 민간 주도의 우주개발 시대를 의미하는 ‘뉴 스페이스(New Space)’에 대응하겠단 취지다. 이통3사 중에선 KT가 가장 적극적이다.

KT는 52년간 인공위성 사업을 영위해 온 KT SAT(샛)을 전면으로 내세워 사업을 준비하고 있다. KT 샛은 이 기간 쌓은 ‘국제 협력’을 바탕으로 스페이스 데이터 사업 진출을 준비 중이다. 지난 2월 미국 소재 위성영상 제공 및 분석기업인 ‘블랙스카이’와 협력을 시작, 고해상도의 위성 이미지를 공급받을 수 있는 기반을 마련했다. 지난 4월에는 AI기술 기반 공간정보분석기업인 ‘오비탈인사이트’와도 손을 잡았다. 이를 통해 공간정보분석 서비스를 우리나라 시장에 최초로 제공할 수 있게 됐다.

KT 샛은 구체적으로 △위성 이미지 수집 △데이터 전처리 △우주 데이터 분석·활용 등을 새로운 사업 범위로 삼았다. 데이터 전처리는 자료 원본(raw data)을 목적과 방법에 맞는 형태로 처리하기 위해 불필요한 정보를 제거하는 식의 가공 과정을 말한다.

KT 샛은 우선 국내 시장을 대상으로 레퍼런스를 확보, 스페이스 데이터 사업의 서비스 포트폴리오를 다각화를 추진한다. 향후 미래 성장 가능성이 높은 데이터 분석·활용 등의 부가가치 분야에 집중함으로써 세계 전역으로 사업 영역을 확대하겠다는 계획이다.

SKT는 과기정통부가 올 3분기 추진할 것으로 전망되는 ‘저궤도 군집 위성통신 시스템 개발사업’에 참여를 준비 중인 것으로 전해진다. 또 자회사인 SK텔링크를 통해 해외 위성통신 사업자와의 협력을 추진 중이다. 위성을 기반으로 한 6G 통신 서비스 공급을 준비하기 위한 목적으로 보인다.

LG유플러스 역시 인공위성과 관련된 기술을 확보하기 위해 한국과학기술원(KAIST·카이스트)과 공동 연구를 수행한 바 있다. 지난해 12월부터 이준구 카이스트 교수 연구팀 등과 6개월간 세계 최초로 상용화된 D-웨이브(D-wave) 양자컴퓨터를 사용, 6G 저궤도위성 네트워크망 구조 최적화 연구를 진행했다. 양측은 이번 연구를 통해 양자컴퓨터로 하나의 위성에서 통신할 수 있는 주변 위성의 개수와 거리를 정하고, 양자컴퓨터로 빠르게 계산하는 데 성공했다. 글로벌 통신장비 제조업체 노키아와는 5G 어드밴스드(Advanced·5G의 진화 단계) 및 6G 분야 연구개발을 협력하는 중이다.

한컴그룹에선 2020년 합류한 우주·드론 전문기업 한컴인스페이스가 스페이스 데이터 사업을 담당하고 있다.

한컴인스페이스는 지난 5월 국내 첫 지구관측용 민간위성 ‘세종1호’를 발사했다. 현재 정상 운용에 들어선 세종1호는 5m 해상도의 다중밴드 위성으로 농업, 산림 등 다양한 분야에서 위성영상 및 분석정보를 제공할 수 있다.

한컴인스페이스는 세종1호를 통해 획득한 데이터를 아시아 및 중동 지역 기업들을 대상으로 판매할 전략을 추진하고 있다. 해당 국가들은 농업 지역이 넓고 분쟁이 잦아 스페이스 데이터 수요가 높다. 한컴 측은 “이번 세종1호 발사를 통해 인공위성과 드론은 물론 완성형 초고해상도 센서를 기반으로 세계에서 유일하게 우주·항공·지상을 모두 커버하는 영상 데이터 서비스 벨트를 구축하게 된다”고 전했다.

한컴은 2023년 상반기에 세종2호를 추가로 발사할 계획이다. 하반기엔 3호와 4호의 발사를, 2024년엔 5호 발사를 준비 중이다. 5년 내 50기 이상을 발사, 군집위성 체계를 구축한다는 목표를 갖고 있다.

네이버는 클라우드 기반 위성 서비스 확대에 나선다. 네이버클라우드를 중심으로 최근 우주 위성체계 개발 기업 쎄트렉아이 등 국내 기업과 협력 체계를 구축하고 있다. 위성 정보를 안정적으로 처리하는 데 ‘클라우드 기술’을 활용하는 게 사업 기획의 핵심이다.

LIG넥스원은 최근 영국 판보로 에어쇼에서 아이스아이(ICEYE)와 ‘위성산업분야 업무협약(MOU)’을 체결했다. 양사는 이번 협약을 통해 △초소형 위성분야 △영상 활용·서비스분야 △뉴 스페이스 분야 기술·동향 교류 등의 협력을 추진한다. LIG넥스원은 주로 인공위성 탑재체로 활용되는 초정밀영상레이더(SAR) 기술을 보유한 기업이다. 회사는 악천후·구름 등에도 활용 가능한 SAR의 영상처리 기술을 기반으로 스페이스 데이터 분야뿐 아니라 위성 제조 분야에서도 성과를 낼 계획이다.

KAI는 카이스트와 손잡았다. 카이스트와의 협력을 통해 위성이 전송하는 사진을 저해상도에서 고해상도로 변환하는 초해상화 기술 등을 확보할 방침이다. 회사 측은 “우주산업 고도화에 필요한 핵심기술 공동 연구개발로 세계 시장에 본격 진출한다”고 전했다. 지난 4월 항공 영상분석 전문업체인 메이사메이사와법인(JV) 메이사메이사플래닛(Meissaanet)을 설립하기도 했다.

업계 관계자는 “정부의 육성 정책에 맞춰 국내 굴지의 기업들이 각자의 장점을 살려 우주산업 시장에 진출하기 위한 움직임이 활발하다”며 “다만 이 같은 사업들이 시장에 안착하려면 10년 정도의 시간이 필요할 것”이라고 말했다."""

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize
from konlpy.tag import Mecab

# 문장 분리
def get_sentences(txt):
    return sent_tokenize(txt)

# 토큰화 
def get_words(txt):
    mecab = Mecab()
    return [t[0] for t in mecab.pos(txt) if (t[1][0] == 'N') & (len(t[0])>1)]

# %%
# 단어(토큰)의 가중치 계산 및 범위에 포함되는 토큰 식별 
def get_keywords(word_list , min_ratio=0.001, max_ratio=0.5) :
    assert (min_ratio < 1 and max_ratio < 1)
    
    # 토큰별로 빈도수 카운팅
    count_dict = {}    
    for word in word_list:
        count_dict.setdefault(word , 0)
        count_dict[word] +=1
    
    # 분석 문서의 총 토큰수 대비 해당 토큰의 빈도 비율
    keywords = set()
    for word , cnt in count_dict.items():
        word_percentage = count_dict[word] / len (word_list)
        
        # 사전 정의한 비율내에 포함 된 경우 키워드에 추가
        if word_percentage <= max_ratio and word_percentage >=min_ratio:
            keywords.add(word)
    return keywords

get_keywords(['바나나','사과','바나나','바나나','포도'])
# Out:
# {'사과', '포도'}

# %% [markdown]
# ## 사회 데이터 적용

# %%
with open('사회1주차_내용.txt', 'r', encoding='UTF-8') as f:
    contents = f.readlines()
    for content in contents:
        print(content)
        print(type(content))
        break
# Out:
# 대교협, 등록금 규제완화 및 지역사회 혁신위한 지원 확대 요청김헌영 강원대 총장 주제발표…정부, 등록금 자율화 검토 안해
#
# <class 'str'>

# %% [markdown]
# ### 1) 토큰화

# %%
from nltk.tokenize import sent_tokenize
from konlpy.tag import Mecab

# 문장 분리
def get_sentences(txt):
    return sent_tokenize(txt)

# 토큰화 
def get_words(txt):
    mecab = Mecab()
    taggings = ['NNG', 'NNP','NNBC','NG','VV','VA','VX','VCP','VCN','MM','SL','SH','SN']
    return [t[0] for t in mecab.pos(txt) if (t[1] in taggings) & (len(t[0])>1)]

# %% [markdown]
# ### 2) 중요 단어 결정

# %%
contents_one =  " ".join(contents)

# %%
contents_one #런타임 끊어짐

# %%
contents
# Out:
# ['대교협, 등록금 규제완화 및 지역사회 혁신위한 지원 확대 요청김헌영 강원대 총장 주제발표…정부, 등록금 자율화 검토 안해\n',
#  '◇김헌영 강원대 총장은 지난 31일 한국대학교육협의회 전국총회에 참석, 주제발표를 하면서 적극적인 지방 대학 문제 대책 마련과 지역-대학 협력체계 구축이 중요하다고 중심으로 미충원 문제와 재정난이 심각해지자 전국 대학 총장들이 등록금 규제 완화와 지역사회 혁신을 위한 지원 확대 등을 요청하고 나섰다. 하지만 정부는 지금 단계에서 등록금 자율화는 검토하지 않고 있다며 (대교협)가 지난 31일 서울에서 개최한 전국총회에서 김헌영 강원대 총장을 비롯한 전국 4년제 대학 148개교 총장은 대학 균형 발전에 대한 현장의 의견을 전달하고, 정부가 전 사회적인 대책 마련에 나서야 한다고 (국가균형발전위원회 지방대학활성화 특별위원장) 강원대 총장은 주제발표를 통해 "청년층의 수도권 유입과 맞물려 신입생 미충원 문제는 지역대학과 전문대에 집중되고 있다"며 "그동안 정부가 추진한 대학 구조조정 정책은 성과지표 위주의 평가에 따른 대학 서열화 문제를 낳았고, 지방대학·소규모대학·전문대학에 부담이 집중됐다"고 "교육 예산의 대부분이 유·초·중등교육에 치중돼 있으며, 고등교육과 평생·직업교육 예산 비중은 매우 미미하다"고 강조했다. 특히 "국·공립대는 무상등록금을 도입하고, 사립대는 등록금 규제를 완하해야 한다"고 대해 이주호 부총리 겸 교육부장관은 "지금 단계에서는 등록금 자율화에 대해선 정부 차원에서 검토하고 있지 않다"고 말했다. 또 "모든 대학이 다 살아남지 못한다는 점을 냉철하게 받아들여야 한다"며 "구조개혁을 다른 대학보다 열심히 하는 대학은 반드시 살아남아 지역발전에 기여할 수 있도록 돕겠다"고 강조했다.\n',
#  '최종 합격자 86명 중 남성 45명, 여성 41명전국 흐름과 대조…산간벽지 많은 환경 영향\n',
# ...

# %%
# 단어(토큰)의 가중치 계산 및 범위에 포함되는 토큰 식별 
def get_keywords(word_list , min_ratio=0.001, max_ratio=0.5) :
    assert (min_ratio < 1 and max_ratio < 1)
    
    # 토큰별로 빈도수 카운팅
    count_dict = {}    
    for word in word_list:
        count_dict.setdefault(word , 0)
        count_dict[word] +=1
    
    # 분석 문서의 총 토큰수 대비 해당 토큰의 빈도 비율
    keywords = set()
    for word , cnt in count_dict.items():
        word_percentage = count_dict[word] / len (word_list)
        
        # 사전 정의한 비율내에 포함 된 경우 키워드에 추가
        if word_percentage <= max_ratio and word_percentage >=min_ratio:
            keywords.add(word)
    return keywords

get_keywords(['바나나','사과','바나나','바나나','포도'])
# Out:
# {'사과', '포도'}

# %% [markdown]
# ### 3) 문장 중요도 계산

# %%
# 문장의 가중치 계산
def get_sentence_weight (sentence , keywords):
    sen_list = sentence.split(' ')
    window_start = 0; window_end = -1;
    
    # 문장내에서 윈도 시작 위치 탐색
    # 범위내 속한 키워드가 등장하는 첫번째 위치 계산
    for i in range(len(sen_list)):
        if sen_list[i] in keywords:
            window_start = i
            break
    
    # 문장내에서 윈도 종료 위치 탐색
    # 범위내 속한 키워드가 등장하는 마지막 위치 계산
    for i in range(len(sen_list) - 1 , 0 , -1) :
        if sen_list[i] in keywords:
            window_end = i
            break
    
    # 윈도의 시작위치가 종료위치보다 큰경우 => 분석할 단어(토큰)가 없는 경우 종료
    if window_start > window_end :
        return 0
    
    # 윈도 크기 계산
    window_size = window_end - window_start + 1
    
    # 분석 대상 문장 중 범위(0.001 ~ 0.5)에 포함된 토큰 개수 카운팅
    keywords_cnt =0
    for w in sen_list :
        if w in keywords:
            keywords_cnt +=1
    
    # (분석 대상 문장 중 범위(0.001 ~ 0.5)에 포함된 토큰 개수) / 윈도사이즈
    return keywords_cnt*keywords_cnt *1.0 / window_size

# %%
# 문서 요약
def summarize(content ,max_no_of_sentences = 10):
    
    txt = content
    # 단어(토큰) 분리
    word_list = get_words(txt)
    print(word_list)
    
    # 단어(토큰) 가중치 계산 및 범위 내 포함 단어(토큰) 추출
    keywords = get_keywords(word_list , 0.001 , 0.5)
    print(keywords)
    
    sentence_list = get_sentences(txt)
    sentence_weight = []

    # 문장별 가중치 계산
    for sen in sentence_list :
        sentence_weight.append ((get_sentence_weight(sen , keywords) ,sen))
           
    # 문장별 가중치 역순 계산
    sentence_weight.sort(reverse = True)
    #print(sentence_weight)
    ret_list = []
    ret_cnt = min(max_no_of_sentences  , len(sentence_list))
    
    for i in range (ret_cnt) :
        ret_list.append (str(sentence_weight[i][0])  + ' : ' 
                         + sentence_weight[i][1])
    
    return ret_list

# %%
contents[0]
# Out:
# '대교협, 등록금 규제완화 및 지역사회 혁신위한 지원 확대 요청김헌영 강원대 총장 주제발표…정부, 등록금 자율화 검토 안해\n'

# %%
li = summarize (contents[0] ,  5)
for s in li:
    print(s)
# Out:
# ['교협', '등록금', '규제', '완화', '지역', '사회', '혁신', '지원', '확대', '요청', '김헌영', '강원', '총장', '주제', '발표', '정부', '등록금', '자율', '검토']
# {'주제', '지원', '교협', '사회', '강원', '요청', '자율', '확대', '김헌영', '발표', '총장', '혁신', '등록금', '정부', '검토', '지역', '완화', '규제'}
# 2.5714285714285716 : 대교협, 등록금 규제완화 및 지역사회 혁신위한 지원 확대 요청김헌영 강원대 총장 주제발표…정부, 등록금 자율화 검토 안해

# %%
li
# Out:
# ['2.5714285714285716 : 대교협, 등록금 규제완화 및 지역사회 혁신위한 지원 확대 요청김헌영 강원대 총장 주제발표…정부, 등록금 자율화 검토 안해']

# %%
li = summarize (contents_one ,  5)
for s in li:
    print(s)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-5be914133576> in <cell line: 1>()
# ----> 1 li = summarize (contents_one ,  5)
#       2 for s in li:
#       3     print(s)
#
# <ipython-input-11-907700a09c11> in summarize(content, max_no_of_sentences)
#       4     txt = content
#       5     # 단어(토큰) 분리
# ----> 6     word_list = get_words(txt)
#       7     print(word_list)
#       8
#
# <ipython-input-5-f9326ceedeaa> in get_words(txt)
#      10     mecab = Mecab()
#      11     taggings = ['NNG', 'NNP','NNBC','NG','VV','VA','VX','VCP','VCN','MM','SL','SH','SN']
# ---> 12     return [t[0] for t in mecab.pos(txt) if (t[1] in taggings) & (len(t[0])>1)]
#
# /usr/local/lib/python3.9/dist-packages/konlpy/tag/_mecab.py in pos(self, phrase, flatten, join)
#     112             if flatten:
#     113                 result = self.tagger.parse(phrase)
# ...

# %%
Text = contents[0]

# %%
from konlpy.tag import Mecab

# 문장간 유사도 측정 (자카드 유사도 사용)
def sentence_similarity(sentence1, sentence2):
    mecab = Mecab()
    # 각 문장을 소문자로 변환
    sentence1 = [word for word in mecab.pos(sentence1) if word[1][0] in ['N', 'V']]
    sentence2 = [word for word in mecab.pos(sentence2) if word[1][0] in ['N', 'V']]

    union = set(sentence1).union(set(sentence2))
    intersection = set(sentence1).intersection(set(sentence2))
    return len(intersection)/len(union) 

sentence_similarity('나는 치킨을 좋아해','나는 치킨을 싫어해')
# Out:
# 0.5

# %%
import numpy as np
def buildMatrix(sentences):
    score = np.ones(len(sentences) ,dtype=np.float32) # zeros도 가능, 결국 나한테 들어오는 엣지 가중치들을 통해 최초 점수를 가지게 되므로
    # 문장별로 그래프 edge를 Matrix 형태로 생성
    weighted_edge = np.zeros((len(sentences), len(sentences))
                             ,dtype=np.float32)

    for i in range(len(sentences)):
        for j in range(len(sentences)):
            if i == j: continue
            weighted_edge[i][j] = sentence_similarity(sentences[i], sentences[j])
    
    # normalize 
    for i in range(len(weighted_edge)):
        score[i] = weighted_edge[i].sum()
        weighted_edge[i] /= score[i]

    return score, weighted_edge

Text = "딸기 바나나 사과 파인애플 수박. 바나나 사과 딸기 포도. 복숭아 수박. 파인애플 사과 딸기 바나나."
buildMatrix(sent_tokenize(Text))
# Out:
# (array([1.4666667 , 1.1       , 0.16666667, 1.4000001 ], dtype=float32),
#  array([[0.        , 0.3409091 , 0.11363637, 0.54545456],
#         [0.45454544, 0.        , 0.        , 0.54545456],
#         [1.        , 0.        , 0.        , 0.        ],
#         [0.57142854, 0.4285714 , 0.        , 0.        ]], dtype=float32))

# %%
def scoring(A, P, eps=0.0001, d=0.85, max_iter = 50):
    for iter in range(0,max_iter):
        newP = (1 - d) + d * A.T.dot(P)

        if abs((newP - P).sum()) <= eps:
            return newP
        P = newP
    return newP

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize

def summarize(text, n=10):
    text = sent_tokenize(text)
    score_init, weighted_edge = buildMatrix(text) 
    score = scoring(weighted_edge, score_init)
    
    sorted_scores = sorted(enumerate(score), key=lambda item: item[1], reverse=True)[:n]
    return [(text[s[0]], s[1]) for s in sorted_scores ]

# %%
summary = summarize(doc, 3)

for sent in summary :
    print(sent)
# Out:
# ('또 다른 우주 산업계 관계자는 국내 기업이 스페이스 데이터 사업에서 올릴 수 있는 성과가 많다고 설명했다.', 1.7198738)
# ('정부는 과학기술정보통신부(과기정통부)를 중심으로 스페이스 데이터 시장의 기반이 되는 인공위성 분야는 물론 우주 발사체 등을 개발하는 사업을 추진하고 있다.', 1.6709554)
# ('26일 업계에 따르면 정보통신기술(ICT) 업체부터 방산 기업까지 정부의 우주산업 육성 계획에 맞춰 스페이스 데이터 시장 진출을 준비하고 있다.', 1.6401098)
